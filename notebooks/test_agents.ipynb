# %% [markdown]
# # Blog Post Creator - Agent Testing Notebook
#
# This notebook allows you to interactively test all three agent implementations:
# 1. **CrewAI Multi-Agent System** (Recommended)
# 2. **LangChain Simple Chain** (Step-by-step)
# 3. **LangChain Full Agent** (Autonomous)
#
# ## Setup
#
# Make sure you have:
# - Created a `.env` file with all required API keys
# - Installed all dependencies from `requirements.txt`
# - Activated your virtual environment

# %%
# Import required modules
import sys
import os

# Add parent directory to path for imports
sys.path.insert(0, os.path.abspath('..'))

from src.utils.config import validate_config
from src.agents.langchain_agent import BlogPostAgent, SimpleResearchWriter
from src.agents.crew_agent import BlogPostCrew

print("✓ Imports successful!")
# Out:
# ✓ Imports successful!

# %% [markdown]
# ## Validate Configuration
#
# First, let's validate that all required environment variables are set:

# %%
try:
    validate_config()
    print("✓ Configuration validated successfully!")
    print("All required API keys and settings are present.")
except ValueError as e:
    print(f"❌ Configuration Error: {e}")
    print("\nPlease check your .env file and ensure all required variables are set.")
# Out:
# ✓ Configuration validated successfully!
# All required API keys and settings are present.

# %% [markdown]
# ## Define Your Topic
#
# Set the topic for your blog post:

# %%
# Example topics - choose one or create your own
topics = {
    "ai_trends": """Write a blog post about Galata tower and mention al books which mentioned this tower in it.""",
}

# Select a topic or define your own
topic = topics["ai_trends"]  # Change this to select different topics

# Or define a custom topic:
# topic = "Your custom topic here..."

print("Selected Topic:")
print("=" * 60)
print(topic)
print("=" * 60)
# Out:
# Selected Topic:
# ============================================================
# Write a blog post about Galata tower and mention al books which mentioned this tower in it.
# ============================================================

# %% [markdown]
# ## Option 1: CrewAI Multi-Agent System (Recommended)
#
# Test the CrewAI implementation with specialized agents working together.

# %%
print("\n" + "=" * 60)
print("Testing CrewAI Multi-Agent System")
print("=" * 60 + "\n")

# Create the crew
crew = BlogPostCrew()

# Create and publish the post
result = crew.create_and_publish_post(topic)

print("\n" + "=" * 60)
print("Result:")
print("=" * 60)
print(result)
# Out:
# ============================================================
# Testing CrewAI Multi-Agent System
# ============================================================
#
#
# ============================================================
# Starting CrewAI Blog Post Creation Process
# ============================================================
#
#
# 📋 Task Started: Research the following topic thoroughly:
#
# Write a blog post about Galata tower and mention al books
#    Agent: Content Researcher
#
# 📋 Task Started: Based on the research findings and the topic: Write a blog post about Galata tower and mention al bo
#    Agent: Blog Content Writer
#
# 📋 Task Started: Write a comprehensive blog post about: Write a blog post about Galata tower and mention al books whi
#    Agent: Blog Content Writer
#
# 📋 Task Started: Based on the blog post title and content, generate 3-5 relevant tags.
# Tags should be:
# - Relevant to
#    Agent: Blog Content Writer
#
# 📋 Task Started: Publish the blog post to Ghost CMS.
#
# Use the publish_to_ghost tool with:
# - title: from the title tas
#    Agent: Content Publisher
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 177532dc-c0ae-4fd4-9650-3616f9be6358                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Researcher                                                                                      │
# │                                                                                                                 │
# │  Task: Research the following topic thoroughly:                                                                 │
# │                                                                                                                 │
# │  Write a blog post about Galata tower and mention al books which mentioned this tower in it.                    │
# │                                                                                                                 │
# │  Your research should include:                                                                                  │
# │  - Current trends and developments                                                                              │
# │  - Key facts and statistics                                                                                     │
# │  - Expert opinions and insights                                                                                 │
# │  - Relevant examples and case studies                                                                           │
# │  - Any recent news or updates                                                                                   │
# │                                                                                                                 │
# │  Provide a comprehensive research summary with all key findings.                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Content Researcher                                                                                      │
# │                                                                                                                 │
# │  Thought: I need to gather detailed and comprehensive information about Galata Tower, including its history,    │
# │  current trends, key facts and statistics, expert opinions, and any recent news or updates. Additionally, I     │
# │  must find books that mention Galata Tower to fulfill the complete requirements of the task.                    │
# │                                                                                                                 │
# │  Using Tool: search_web                                                                                         │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# ✓ Task COMPLETED: Research the following topic thoroughly:
#
# Write a blog post about Galata tower and mention al books
#    Duration: 119.31s
#    Output: 3006 characters
#
# ✓ Task COMPLETED: Based on the research findings and the topic: Write a blog post about Galata tower and mention al bo
#    Duration: 119.33s
#    Output: 29 characters
#
# ✓ Task COMPLETED: Write a comprehensive blog post about: Write a blog post about Galata tower and mention al books whi
#    Duration: 119.33s
#    Output: 3034 characters
#
# ✓ Task COMPLETED: Based on the blog post title and content, generate 3-5 relevant tags.
# Tags should be:
# - Relevant to
#    Duration: 119.33s
#    Output: 85 characters
#
# ✓ Task COMPLETED: Publish the blog post to Ghost CMS.
#
# Use the publish_to_ghost tool with:
# - title: from the title tas
#    Duration: 119.33s
#    Output: 175 characters
#
# ============================================================
# Running Quality Evaluation...
# ============================================================
#
#
# ======================================================================
# 📝 CONTENT QUALITY EVALUATION
# ======================================================================
#
# Overall Score: 57.5/100 (Grade: F)
#
# Detailed Scores:
#   • Readability: 65.0/100
#   • Structure: 100.0/100
#   • SEO: 35.0/100
#   • Completeness: 30.0/100
#
# ⚠️  Issues Found (7):
#   • Content is difficult to read (score: 22.3)
#   • Content requires college-level reading (grade 15.8)
#   • Title too short (29 chars). SEO optimal: 50-70
#   • Content too short (436 words). Target: 800-1500
#   • Title keywords barely appear in content
#   • Sections lack depth - need more content per section
#   • Content critically short - not viable for publication
#
# 💡 Recommendations (7):
#   • Use shorter sentences and simpler words
#   • Simplify complex sentences
#   • Expand title to 50-70 characters
#   • Expand content with more details and examples
#   • Use title keywords naturally throughout content
#   • Consider adding a clear conclusion
#   • Expand each section with more details
#
# ======================================================================
#
#
# ======================================================================
# 🤖 AGENT PERFORMANCE EVALUATION
# ======================================================================
#
# Overall Score: 76.75/100 (Grade: C)
#
# Detailed Scores:
#   • Efficiency: 40.0/100
#   • Reliability: 100.0/100
#   • Quality: 85.0/100
#
# ✓ Strengths (4):
#   • Very fast execution (0.0s)
#   • Zero errors during execution
#   • All tasks completed successfully
#   • 2 tasks with substantial output
#
# ✗ Areas for Improvement (3):
#   • Very few tool calls - may lack thoroughness
#   • 5 slow tasks detected
#   • Task produced very short output (29 chars)
#
# ======================================================================
#
# ✓ Evaluation report exported to evaluation_1763090442.json
#
# ⚠️  Warning: Content quality score (57.5) is below minimum threshold (70.0)
# Consider regenerating or improving the content before publishing.
#
#
#
# ======================================================================
# 📊 AGENT OBSERVABILITY SUMMARY
# ======================================================================
#
# ⏱️  Total Execution Time: 120.24 seconds
# 📝 Total Tasks: 5
# 🤖 Total Agents: 0
#
# ──────────────────────────────────────────────────────────────────────
# 🤖 AGENT BREAKDOWN
# ──────────────────────────────────────────────────────────────────────
#
# ──────────────────────────────────────────────────────────────────────
# 📋 TASK BREAKDOWN
# ──────────────────────────────────────────────────────────────────────
#
# Task 1: Research the following topic thoroughly:
#
# Write a blog post about Galata tower and mention al books
#   • Agent: Content Researcher
#   • Status: completed
#   • Duration: 119.31s
#   • Output Length: 3006 characters
#
# Task 2: Based on the research findings and the topic: Write a blog post about Galata tower and mention al bo
#   • Agent: Blog Content Writer
#   • Status: completed
#   • Duration: 119.33s
#   • Output Length: 29 characters
#
# Task 3: Write a comprehensive blog post about: Write a blog post about Galata tower and mention al books whi
#   • Agent: Blog Content Writer
#   • Status: completed
#   • Duration: 119.33s
#   • Output Length: 3034 characters
#
# Task 4: Based on the blog post title and content, generate 3-5 relevant tags.
# Tags should be:
# - Relevant to
#   • Agent: Blog Content Writer
#   • Status: completed
#   • Duration: 119.33s
#   • Output Length: 85 characters
#
# Task 5: Publish the blog post to Ghost CMS.
#
# Use the publish_to_ghost tool with:
# - title: from the title tas
#   • Agent: Content Publisher
#   • Status: completed
#   • Duration: 119.33s
#   • Output Length: 175 characters
#
# ──────────────────────────────────────────────────────────────────────
# 💰 TOKEN USAGE & COST ESTIMATES
# ──────────────────────────────────────────────────────────────────────
#
#   • Input Tokens (est.): 0
#   • Output Tokens (est.): 1,580
#   • Total Tokens (est.): 1,580
#   • Estimated Cost: $0.0948 USD
#     - Input Cost: $0.0000
#     - Output Cost: $0.0948
#
# ======================================================================
#
# ✓ Metrics exported to crew_metrics_1763090442.json
#
# ============================================================
# Result:
# ============================================================
# ✓ Successfully published!
# Title: Galata Tower: A Timeless Emblem of Istanbul's Heritage
# URL: https://storylandtravels.com/galata-tower-a-timeless-emblem-of-istanbuls-heritage/

# %% [markdown]
# ### CrewAI with Custom Settings
#
# You can customize observability and evaluation settings:

# %%
# Create crew with custom settings
crew_custom = BlogPostCrew(
    llm_provider="openai",  # or "anthropic"
    enable_observability=True,
    enable_evaluation=True
)

# This will track metrics and evaluate content quality
result = crew_custom.create_and_publish_post(topic)
print(result)

# %% [markdown]
# ## Option 2: LangChain Simple Chain
#
# Test the simple step-by-step implementation using LangChain.

# %%
print("\n" + "=" * 60)
print("Testing LangChain Simple Chain")
print("=" * 60 + "\n")

# Create the simple writer
writer = SimpleResearchWriter()

# Create and publish the post
result = writer.create_and_publish_post(topic)

print("\n" + "=" * 60)
print("Result:")
print("=" * 60)
print(result)
# Out:
# ============================================================
# Testing LangChain Simple Chain
# ============================================================
# /Users/osa/Documents/storyland/storyland-agents/post-creator/src/tools/langchain_tools.py:19: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   return TavilySearchResults(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 6
#       3 print("=" * 60 + "\n")
#       5 # Create the simple writer
# ----> 6 writer = SimpleResearchWriter()
#       8 # Create and publish the post
#       9 result = writer.create_and_publish_post(topic)
#
# File ~/Documents/storyland/storyland-agents/post-creator/src/agents/langchain_agent.py:149, in SimpleResearchWriter.__init__(self, llm_provider)
#     147 # Initialize tools
#     148 self.search_tool = TavilySearchTool.create()
# --> 149 from tools import GhostPublishTool
#     150 self.publish_tool = GhostPublishTool()
#
# ModuleNotFoundError: No module named 'tools'

# %% [markdown]
# ## Option 3: LangChain Full Agent
#
# Test the autonomous agent implementation using LangChain's agent framework.

# %%
print("\n" + "=" * 60)
print("Testing LangChain Full Agent")
print("=" * 60 + "\n")

# Create the agent
agent = BlogPostAgent()

# Create and publish the post
result = agent.create_and_publish_post(topic)

print("\n" + "=" * 60)
print("Result:")
print("=" * 60)
print(result)

# %% [markdown]
# ## Test Multiple Topics Sequentially
#
# You can test multiple topics in sequence to compare results:

# %%
# Test multiple topics with CrewAI
test_topics = [
    "The benefits of meditation for busy professionals",
    "Latest developments in quantum computing",
    "How to start a vegetable garden in small spaces"
]

crew = BlogPostCrew()

for i, test_topic in enumerate(test_topics, 1):
    print(f"\n{'='*60}")
    print(f"Test {i}/{len(test_topics)}: {test_topic[:50]}...")
    print(f"{'='*60}\n")
    
    result = crew.create_and_publish_post(test_topic)
    print(f"Result: {result}")

# %% [markdown]
# ## Compare All Three Implementations
#
# Run the same topic through all three implementations to compare:

# %%
comparison_topic = "The impact of AI on healthcare in 2025"

results = {}

# Test CrewAI
print("Testing CrewAI...")
crew = BlogPostCrew()
results["crewai"] = crew.create_and_publish_post(comparison_topic)

# Test Simple Chain
print("\nTesting Simple Chain...")
writer = SimpleResearchWriter()
results["simple_chain"] = writer.create_and_publish_post(comparison_topic)

# Test Full Agent
print("\nTesting Full Agent...")
agent = BlogPostAgent()
results["full_agent"] = agent.create_and_publish_post(comparison_topic)

# Display results
print("\n" + "=" * 60)
print("COMPARISON RESULTS")
print("=" * 60)
for name, result in results.items():
    print(f"\n{name.upper()}:")
    print("-" * 60)
    print(result)

# %% [markdown]
# ## Inspect Evaluation Metrics (CrewAI Only)
#
# If you have evaluation enabled, you can inspect the quality metrics:

# %%
# Create crew with evaluation
from src.utils.evaluation import ContentEvaluator

crew_eval = BlogPostCrew(enable_evaluation=True)

# Create a post
result = crew_eval.create_and_publish_post("Sustainable fashion trends")

# The evaluation metrics will be displayed in the output above
print("\nEvaluation metrics are displayed during the post creation process.")

# %% [markdown]
# ## Debugging and Exploration
#
# Use these cells to explore the agents and debug issues:

# %%
# Inspect agent configuration
from src.utils import config

print("LLM Provider:", config.LLM_PROVIDER)
print("Observability Enabled:", config.ENABLE_OBSERVABILITY)
print("Evaluation Enabled:", config.ENABLE_EVALUATION)
print("Min Quality Score:", config.MIN_QUALITY_SCORE)

# %%
# Test individual tools
from src.tools.crew_tools import TavilySearchTool

search_tool = TavilySearchTool()
search_results = search_tool._run("latest AI developments 2025")
print("Search Results:")
print(search_results)

# %% [markdown]
# ## Quick Test Functions
#
# Convenient functions for quick testing:

# %%
def quick_test_crewai(topic_name):
    """Quickly test CrewAI with a predefined topic."""
    if topic_name in topics:
        topic = topics[topic_name]
    else:
        topic = topic_name
    
    crew = BlogPostCrew()
    return crew.create_and_publish_post(topic)

def quick_test_simple(topic_name):
    """Quickly test Simple Chain with a predefined topic."""
    if topic_name in topics:
        topic = topics[topic_name]
    else:
        topic = topic_name
    
    writer = SimpleResearchWriter()
    return writer.create_and_publish_post(topic)

# Usage:
# result = quick_test_crewai("ai_trends")
# result = quick_test_simple("Custom topic here")

# %% [markdown]
# ## Notes and Observations
#
# Use this space to record your observations about different implementations:
#
# ### CrewAI Multi-Agent:
# - Pros:
# - Cons:
# - Notes:
#
# ### LangChain Simple Chain:
# - Pros:
# - Cons:
# - Notes:
#
# ### LangChain Full Agent:
# - Pros:
# - Cons:
# - Notes:
